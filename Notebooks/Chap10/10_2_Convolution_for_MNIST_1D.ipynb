# %% [markdown]
# <a href="https://colab.research.google.com/github/Erik-Hansen96/CSCI167/blob/main/Notebooks/Chap10/10_2_Convolution_for_MNIST_1D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 10.2: Convolution for MNIST-1D**
#
# This notebook investigates a 1D convolutional network for MNIST-1D as in figure 10.7 and 10.8a.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-guehvvp6
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-guehvvp6
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.10.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=abeaeaf1559df9585d105692c09be5fa779202b6a9f072821a51e1a2cc112784
#   Stored in directory: /tmp/pip-ephem-wheel-cache-4j6r1cdy/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# TODO Create a model with the following layers
# 1. Convolutional layer, (input=length 40 and 1 channel, kernel size 3, stride 2, padding="valid", 15 output channels )
# 2. ReLU
# 3. Convolutional layer, (input=length 19 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels )
# 4. ReLU
# 5. Convolutional layer, (input=length 9 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels)
# 6. ReLU
# 7. Flatten (converts 4x15) to length 60
# 8. Linear layer (input size = 60, output size = 10)
# References:
# https://pytorch.org/docs/1.13/generated/torch.nn.Conv1d.html?highlight=conv1d#torch.nn.Conv1d
# https://pytorch.org/docs/stable/generated/torch.nn.Flatten.html
# https://pytorch.org/docs/1.13/generated/torch.nn.Linear.html?highlight=linear#torch.nn.Linear

# NOTE THAT THE CONVOLUTIONAL LAYERS NEED TO TAKE THE NUMBER OF INPUT CHANNELS AS A PARAMETER
# AND NOT THE INPUT SIZE.
model = nn.Sequential(
    nn.Conv1d(in_channels=1, out_channels=15, kernel_size=3, stride=2, padding=0),
    nn.ReLU(),
    nn.Conv1d(in_channels=15, out_channels=15, kernel_size=3, stride=2, padding=0),
    nn.ReLU(),
    nn.Conv1d(in_channels=15, out_channels=15, kernel_size=3, stride=2, padding=0),
    nn.ReLU(),
    nn.Flatten(),
    nn.Linear(in_features=60, out_features=10)
)
# Replace the following function:
model = nn.Sequential(
nn.Flatten(),
nn.Linear(40, 100),
nn.ReLU(),
nn.Linear(100, 100),
nn.ReLU(),
nn.Linear(100, 10))

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# create 100 dummy data points and store in data loader class
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long')).long()
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long')).long()

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch[:,None,:])
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train[:,None,:])
  pred_val = model(x_val[:,None,:])
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()

# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='validation')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('Part I: Validation Result %3.2f'%(errors_val[-1]))
ax.legend()
plt.show()
# Out:
# Epoch     0, train loss 1.580142, train error 60.67,  val loss 1.648042, percent error 63.80
# Epoch     1, train loss 1.319122, train error 47.78,  val loss 1.455009, percent error 56.70
# Epoch     2, train loss 1.163681, train error 42.47,  val loss 1.352089, percent error 52.40
# Epoch     3, train loss 0.969808, train error 34.85,  val loss 1.221540, percent error 47.60
# Epoch     4, train loss 0.855310, train error 30.68,  val loss 1.150674, percent error 45.10
# Epoch     5, train loss 0.753520, train error 25.78,  val loss 1.082916, percent error 41.00
# Epoch     6, train loss 0.690871, train error 24.55,  val loss 1.099905, percent error 41.20
# Epoch     7, train loss 0.611691, train error 20.85,  val loss 1.083528, percent error 40.30
# Epoch     8, train loss 0.585119, train error 20.68,  val loss 1.131733, percent error 40.70
# Epoch     9, train loss 0.497564, train error 15.97,  val loss 1.054371, percent error 38.20
# Epoch    10, train loss 0.461700, train error 14.90,  val loss 1.128353, percent error 39.90
# Epoch    11, train loss 0.387873, train error 11.62,  val loss 1.078530, percent error 40.00
# Epoch    12, train loss 0.342859, train error 10.70,  val loss 1.090291, percent error 38.20
# Epoch    13, train loss 0.376932, train error 14.07,  val loss 1.206971, percent error 41.20
# Epoch    14, train loss 0.305959, train error 9.85,  val loss 1.175075, percent error 38.60
# Epoch    15, train loss 0.246149, train error 7.28,  val loss 1.117514, percent error 37.40
# Epoch    16, train loss 0.209443, train error 5.30,  val loss 1.218116, percent error 38.90
# Epoch    17, train loss 0.203737, train error 6.25,  val loss 1.246897, percent error 38.70
# Epoch    18, train loss 0.157324, train error 4.18,  val loss 1.248913, percent error 36.80
# Epoch    19, train loss 0.163359, train error 4.55,  val loss 1.362242, percent error 38.30
# Epoch    20, train loss 0.081636, train error 0.65,  val loss 1.211020, percent error 34.90
# Epoch    21, train loss 0.066076, train error 0.32,  val loss 1.230208, percent error 35.50
# Epoch    22, train loss 0.059597, train error 0.32,  val loss 1.259315, percent error 35.50
# Epoch    23, train loss 0.049239, train error 0.07,  val loss 1.257764, percent error 35.70
# Epoch    24, train loss 0.046550, train error 0.10,  val loss 1.291302, percent error 35.80
# Epoch    25, train loss 0.040973, train error 0.05,  val loss 1.303243, percent error 36.00
# Epoch    26, train loss 0.037962, train error 0.00,  val loss 1.323294, percent error 36.20
# Epoch    27, train loss 0.034473, train error 0.00,  val loss 1.323957, percent error 35.70
# Epoch    28, train loss 0.032586, train error 0.03,  val loss 1.348414, percent error 35.80
# Epoch    29, train loss 0.029826, train error 0.00,  val loss 1.358740, percent error 36.70
# Epoch    30, train loss 0.027787, train error 0.00,  val loss 1.368083, percent error 35.10
# Epoch    31, train loss 0.025949, train error 0.00,  val loss 1.390365, percent error 36.40
# Epoch    32, train loss 0.024098, train error 0.00,  val loss 1.404010, percent error 35.90
# Epoch    33, train loss 0.023002, train error 0.00,  val loss 1.409517, percent error 35.90
# Epoch    34, train loss 0.021700, train error 0.00,  val loss 1.423300, percent error 36.40
# Epoch    35, train loss 0.020592, train error 0.00,  val loss 1.435978, percent error 36.20
# Epoch    36, train loss 0.019447, train error 0.00,  val loss 1.443227, percent error 36.00
# Epoch    37, train loss 0.018638, train error 0.00,  val loss 1.453942, percent error 36.20
# Epoch    38, train loss 0.017653, train error 0.00,  val loss 1.472619, percent error 36.30
# Epoch    39, train loss 0.016838, train error 0.00,  val loss 1.475664, percent error 35.60
# Epoch    40, train loss 0.016283, train error 0.00,  val loss 1.480357, percent error 36.30
# Epoch    41, train loss 0.015901, train error 0.00,  val loss 1.488962, percent error 36.10
# Epoch    42, train loss 0.015538, train error 0.00,  val loss 1.494013, percent error 36.10
# Epoch    43, train loss 0.015240, train error 0.00,  val loss 1.501585, percent error 36.20
# Epoch    44, train loss 0.014999, train error 0.00,  val loss 1.504903, percent error 35.90
# Epoch    45, train loss 0.014622, train error 0.00,  val loss 1.507480, percent error 36.10
# Epoch    46, train loss 0.014503, train error 0.00,  val loss 1.509602, percent error 36.10
# Epoch    47, train loss 0.014127, train error 0.00,  val loss 1.514739, percent error 36.30
# Epoch    48, train loss 0.013883, train error 0.00,  val loss 1.525645, percent error 36.10
# Epoch    49, train loss 0.013591, train error 0.00,  val loss 1.526168, percent error 36.10
# Epoch    50, train loss 0.013333, train error 0.00,  val loss 1.531706, percent error 36.00
# Epoch    51, train loss 0.013093, train error 0.00,  val loss 1.529759, percent error 36.30
# Epoch    52, train loss 0.012847, train error 0.00,  val loss 1.536385, percent error 36.00
# Epoch    53, train loss 0.012605, train error 0.00,  val loss 1.540451, percent error 36.10
# Epoch    54, train loss 0.012380, train error 0.00,  val loss 1.544747, percent error 36.00
# Epoch    55, train loss 0.012176, train error 0.00,  val loss 1.549514, percent error 36.20
# Epoch    56, train loss 0.011978, train error 0.00,  val loss 1.551133, percent error 36.20
# Epoch    57, train loss 0.011765, train error 0.00,  val loss 1.556521, percent error 36.20
# Epoch    58, train loss 0.011610, train error 0.00,  val loss 1.557745, percent error 36.30
# Epoch    59, train loss 0.011419, train error 0.00,  val loss 1.562309, percent error 36.30
# Epoch    60, train loss 0.011288, train error 0.00,  val loss 1.566454, percent error 36.20
# Epoch    61, train loss 0.011188, train error 0.00,  val loss 1.568622, percent error 36.00
# Epoch    62, train loss 0.011105, train error 0.00,  val loss 1.569412, percent error 36.20
# Epoch    63, train loss 0.011023, train error 0.00,  val loss 1.571408, percent error 36.10
# Epoch    64, train loss 0.010934, train error 0.00,  val loss 1.574166, percent error 36.20
# Epoch    65, train loss 0.010848, train error 0.00,  val loss 1.574871, percent error 36.00
# Epoch    66, train loss 0.010763, train error 0.00,  val loss 1.577805, percent error 36.10
# Epoch    67, train loss 0.010684, train error 0.00,  val loss 1.578678, percent error 36.20
# Epoch    68, train loss 0.010605, train error 0.00,  val loss 1.579972, percent error 36.10
# Epoch    69, train loss 0.010527, train error 0.00,  val loss 1.583398, percent error 36.20
# Epoch    70, train loss 0.010451, train error 0.00,  val loss 1.582791, percent error 36.10
# Epoch    71, train loss 0.010371, train error 0.00,  val loss 1.586528, percent error 36.20
# Epoch    72, train loss 0.010297, train error 0.00,  val loss 1.587369, percent error 36.20
# Epoch    73, train loss 0.010217, train error 0.00,  val loss 1.588688, percent error 36.10
# Epoch    74, train loss 0.010149, train error 0.00,  val loss 1.592107, percent error 36.10
# Epoch    75, train loss 0.010070, train error 0.00,  val loss 1.592580, percent error 36.20
# Epoch    76, train loss 0.010006, train error 0.00,  val loss 1.593150, percent error 36.30
# Epoch    77, train loss 0.009925, train error 0.00,  val loss 1.596302, percent error 36.20
# Epoch    78, train loss 0.009861, train error 0.00,  val loss 1.598949, percent error 36.20
# Epoch    79, train loss 0.009788, train error 0.00,  val loss 1.599707, percent error 36.20
# Epoch    80, train loss 0.009747, train error 0.00,  val loss 1.600130, percent error 36.20
# Epoch    81, train loss 0.009713, train error 0.00,  val loss 1.601135, percent error 36.20
# Epoch    82, train loss 0.009678, train error 0.00,  val loss 1.601509, percent error 36.30
# Epoch    83, train loss 0.009646, train error 0.00,  val loss 1.602217, percent error 36.20
# Epoch    84, train loss 0.009611, train error 0.00,  val loss 1.603815, percent error 36.30
# Epoch    85, train loss 0.009579, train error 0.00,  val loss 1.604351, percent error 36.20
# Epoch    86, train loss 0.009545, train error 0.00,  val loss 1.605378, percent error 36.20
# Epoch    87, train loss 0.009512, train error 0.00,  val loss 1.606118, percent error 36.20
# Epoch    88, train loss 0.009480, train error 0.00,  val loss 1.606999, percent error 36.30
# Epoch    89, train loss 0.009447, train error 0.00,  val loss 1.607555, percent error 36.20
# Epoch    90, train loss 0.009415, train error 0.00,  val loss 1.608336, percent error 36.10
# Epoch    91, train loss 0.009383, train error 0.00,  val loss 1.609458, percent error 36.20
# Epoch    92, train loss 0.009353, train error 0.00,  val loss 1.609316, percent error 36.10
# Epoch    93, train loss 0.009320, train error 0.00,  val loss 1.611060, percent error 36.20
# Epoch    94, train loss 0.009291, train error 0.00,  val loss 1.611897, percent error 36.20
# Epoch    95, train loss 0.009259, train error 0.00,  val loss 1.612068, percent error 36.30
# Epoch    96, train loss 0.009227, train error 0.00,  val loss 1.612901, percent error 36.20
# Epoch    97, train loss 0.009195, train error 0.00,  val loss 1.613915, percent error 36.30
# Epoch    98, train loss 0.009166, train error 0.00,  val loss 1.614206, percent error 36.20
# Epoch    99, train loss 0.009135, train error 0.00,  val loss 1.615154, percent error 36.30
