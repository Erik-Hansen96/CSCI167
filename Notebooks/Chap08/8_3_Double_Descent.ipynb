# %% [markdown]
# <a href="https://colab.research.google.com/github/Erik-Hansen96/CSCI167/blob/main/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-zh_id7iw
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-zh_id7iw
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.10.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=6b11d8ab1538a3b929f6daf50b85eefeab3fc2b156dbeb62c34cde7e05eb0463
#   Stored in directory: /tmp/pip-ephem-wheel-cache-5yuhzi3n/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TODO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero? 42
# 2.   At what capacity do you expect the first minima of the double descent curve to appear? 42
# 3. At what capacity do you expect the maximum of the double descent curve to appear? 30

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.302121, train error 89.53,  test loss 2.302762, test error 90.12
# Epoch   100, train loss 1.912617, train error 70.95,  test loss 1.758533, test error 69.18
# Epoch   200, train loss 1.896924, train error 69.65,  test loss 1.752479, test error 68.53
# Epoch   300, train loss 1.892699, train error 70.18,  test loss 1.736681, test error 69.05
# Epoch   400, train loss 1.896535, train error 70.62,  test loss 1.733057, test error 68.88
# Epoch   500, train loss 1.893259, train error 70.32,  test loss 1.745043, test error 68.78
# Epoch   600, train loss 1.894999, train error 70.50,  test loss 1.729143, test error 68.32
# Epoch   700, train loss 1.891499, train error 71.38,  test loss 1.728489, test error 69.28
# Epoch   800, train loss 1.889814, train error 70.12,  test loss 1.727675, test error 68.22
# Epoch   900, train loss 1.898514, train error 70.80,  test loss 1.737729, test error 69.72
# Training model with   4 hidden variables
# Epoch     0, train loss 2.293550, train error 88.18,  test loss 2.295690, test error 88.00
# Epoch   100, train loss 1.755228, train error 64.25,  test loss 1.592993, test error 61.60
# Epoch   200, train loss 1.737272, train error 63.55,  test loss 1.577893, test error 61.58
# Epoch   300, train loss 1.726984, train error 63.40,  test loss 1.581468, test error 60.92
# Epoch   400, train loss 1.725793, train error 63.78,  test loss 1.592426, test error 61.60
# Epoch   500, train loss 1.724520, train error 62.88,  test loss 1.594330, test error 60.42
# Epoch   600, train loss 1.725239, train error 63.60,  test loss 1.596063, test error 61.58
# Epoch   700, train loss 1.726348, train error 63.20,  test loss 1.593806, test error 61.42
# Epoch   800, train loss 1.719682, train error 62.92,  test loss 1.592482, test error 60.97
# Epoch   900, train loss 1.720767, train error 63.22,  test loss 1.589758, test error 61.25
# Training model with   6 hidden variables
# Epoch     0, train loss 2.198428, train error 82.15,  test loss 2.174793, test error 80.65
# Epoch   100, train loss 1.696782, train error 62.55,  test loss 1.538695, test error 60.20
# Epoch   200, train loss 1.673899, train error 61.78,  test loss 1.529875, test error 59.83
# Epoch   300, train loss 1.656955, train error 59.92,  test loss 1.531288, test error 59.50
# Epoch   400, train loss 1.652208, train error 60.83,  test loss 1.536676, test error 59.40
# Epoch   500, train loss 1.644740, train error 59.78,  test loss 1.538803, test error 59.92
# Epoch   600, train loss 1.638897, train error 59.90,  test loss 1.549814, test error 59.92
# Epoch   700, train loss 1.638606, train error 59.70,  test loss 1.557047, test error 60.03
# Epoch   800, train loss 1.637121, train error 59.53,  test loss 1.554740, test error 60.42
# Epoch   900, train loss 1.637434, train error 60.00,  test loss 1.565297, test error 60.30
# Training model with   8 hidden variables
# Epoch     0, train loss 2.256291, train error 88.45,  test loss 2.249316, test error 87.35
# Epoch   100, train loss 1.515602, train error 50.22,  test loss 1.325408, test error 49.45
# Epoch   200, train loss 1.472119, train error 48.90,  test loss 1.320323, test error 48.95
# Epoch   300, train loss 1.458012, train error 48.85,  test loss 1.309205, test error 49.30
# Epoch   400, train loss 1.440717, train error 48.38,  test loss 1.308922, test error 48.38
# Epoch   500, train loss 1.427470, train error 48.15,  test loss 1.308869, test error 48.40
# Epoch   600, train loss 1.424844, train error 48.25,  test loss 1.320706, test error 49.12
# Epoch   700, train loss 1.418154, train error 47.92,  test loss 1.317944, test error 48.53
# Epoch   800, train loss 1.417430, train error 47.47,  test loss 1.318821, test error 48.00
# Epoch   900, train loss 1.423974, train error 48.20,  test loss 1.323323, test error 48.53
# Training model with  10 hidden variables
# Epoch     0, train loss 2.248287, train error 82.53,  test loss 2.237751, test error 81.68
# Epoch   100, train loss 1.504635, train error 52.00,  test loss 1.358292, test error 50.38
# Epoch   200, train loss 1.448191, train error 50.40,  test loss 1.320731, test error 48.30
# Epoch   300, train loss 1.422626, train error 49.17,  test loss 1.330561, test error 48.58
# Epoch   400, train loss 1.408640, train error 48.80,  test loss 1.332736, test error 48.25
# Epoch   500, train loss 1.395241, train error 47.65,  test loss 1.342412, test error 48.97
# Epoch   600, train loss 1.390857, train error 47.95,  test loss 1.345790, test error 49.15
# Epoch   700, train loss 1.388549, train error 48.05,  test loss 1.354236, test error 49.03
# Epoch   800, train loss 1.386124, train error 48.03,  test loss 1.357824, test error 48.50
# Epoch   900, train loss 1.389770, train error 47.65,  test loss 1.367481, test error 49.35
# Training model with  14 hidden variables
# Epoch     0, train loss 2.161090, train error 80.78,  test loss 2.122242, test error 79.50
# Epoch   100, train loss 1.495100, train error 52.15,  test loss 1.425624, test error 54.60
# Epoch   200, train loss 1.429432, train error 49.80,  test loss 1.422798, test error 53.55
# Epoch   300, train loss 1.384312, train error 48.08,  test loss 1.422166, test error 53.12
# Epoch   400, train loss 1.363432, train error 47.58,  test loss 1.426429, test error 52.22
# Epoch   500, train loss 1.338688, train error 46.10,  test loss 1.440103, test error 52.47
# Epoch   600, train loss 1.321955, train error 44.62,  test loss 1.438417, test error 51.97
# Epoch   700, train loss 1.309435, train error 43.92,  test loss 1.428285, test error 50.97
# Epoch   800, train loss 1.307096, train error 44.00,  test loss 1.429234, test error 51.12
# Epoch   900, train loss 1.289243, train error 43.30,  test loss 1.424268, test error 51.17
# Training model with  18 hidden variables
# Epoch     0, train loss 2.134006, train error 80.30,  test loss 2.103018, test error 79.55
# Epoch   100, train loss 1.365592, train error 45.03,  test loss 1.320221, test error 48.67
# Epoch   200, train loss 1.254485, train error 41.72,  test loss 1.298320, test error 48.05
# Epoch   300, train loss 1.203971, train error 40.45,  test loss 1.329838, test error 48.17
# Epoch   400, train loss 1.180013, train error 39.53,  test loss 1.363826, test error 49.08
# Epoch   500, train loss 1.154792, train error 39.33,  test loss 1.401755, test error 48.25
# Epoch   600, train loss 1.140662, train error 38.95,  test loss 1.432842, test error 49.28
# Epoch   700, train loss 1.145936, train error 39.50,  test loss 1.471548, test error 49.67
# Epoch   800, train loss 1.120239, train error 38.40,  test loss 1.461439, test error 49.03
# Epoch   900, train loss 1.108134, train error 37.75,  test loss 1.469913, test error 48.58
# Training model with  22 hidden variables
# Epoch     0, train loss 2.139956, train error 79.75,  test loss 2.087976, test error 78.88
# Epoch   100, train loss 1.302426, train error 43.78,  test loss 1.324276, test error 49.15
# Epoch   200, train loss 1.176936, train error 38.53,  test loss 1.383948, test error 49.12
# Epoch   300, train loss 1.131925, train error 38.08,  test loss 1.444305, test error 49.20
# Epoch   400, train loss 1.065057, train error 35.55,  test loss 1.494503, test error 48.88
# Epoch   500, train loss 1.037040, train error 34.57,  test loss 1.569579, test error 49.03
# Epoch   600, train loss 1.034479, train error 35.32,  test loss 1.659459, test error 50.38
# Epoch   700, train loss 1.007409, train error 33.78,  test loss 1.692375, test error 50.30
# Epoch   800, train loss 1.000139, train error 33.78,  test loss 1.738585, test error 51.38
# Epoch   900, train loss 0.988110, train error 33.07,  test loss 1.789062, test error 51.28
# Training model with  26 hidden variables
# Epoch     0, train loss 2.147637, train error 81.00,  test loss 2.102035, test error 79.30
# Epoch   100, train loss 1.215787, train error 40.85,  test loss 1.313452, test error 48.83
# Epoch   200, train loss 1.054224, train error 35.20,  test loss 1.411643, test error 49.50
# Epoch   300, train loss 0.969383, train error 32.88,  test loss 1.545888, test error 50.90
# Epoch   400, train loss 0.921854, train error 31.75,  test loss 1.664958, test error 51.88
# Epoch   500, train loss 0.887663, train error 30.45,  test loss 1.750553, test error 51.50
# Epoch   600, train loss 0.855770, train error 28.70,  test loss 1.815729, test error 52.42
# Epoch   700, train loss 0.857154, train error 29.12,  test loss 1.885632, test error 52.20
# Epoch   800, train loss 0.821831, train error 27.55,  test loss 1.986057, test error 53.42
# Epoch   900, train loss 0.815071, train error 27.28,  test loss 2.018032, test error 53.00
# Training model with  30 hidden variables
# Epoch     0, train loss 2.207954, train error 80.70,  test loss 2.177559, test error 79.15
# Epoch   100, train loss 1.099653, train error 36.15,  test loss 1.291701, test error 48.92
# Epoch   200, train loss 0.944862, train error 30.25,  test loss 1.447233, test error 50.22
# Epoch   300, train loss 0.865769, train error 29.30,  test loss 1.586789, test error 52.20
# Epoch   400, train loss 0.804779, train error 26.80,  test loss 1.777547, test error 52.78
# Epoch   500, train loss 0.777521, train error 26.97,  test loss 1.934947, test error 54.20
# Epoch   600, train loss 0.772606, train error 26.88,  test loss 2.072259, test error 53.42
# Epoch   700, train loss 0.716984, train error 24.50,  test loss 2.149481, test error 53.97
# Epoch   800, train loss 0.701505, train error 23.30,  test loss 2.239353, test error 53.97
# Epoch   900, train loss 0.678957, train error 22.75,  test loss 2.354206, test error 53.85
# Training model with  35 hidden variables
# Epoch     0, train loss 2.134037, train error 79.20,  test loss 2.090252, test error 78.68
# Epoch   100, train loss 1.002173, train error 31.70,  test loss 1.372228, test error 48.85
# Epoch   200, train loss 0.775795, train error 25.38,  test loss 1.714472, test error 51.90
# Epoch   300, train loss 0.656904, train error 21.32,  test loss 2.077680, test error 53.15
# Epoch   400, train loss 0.581606, train error 18.47,  test loss 2.404410, test error 53.95
# Epoch   500, train loss 0.538380, train error 17.93,  test loss 2.715559, test error 54.62
# Epoch   600, train loss 0.493298, train error 16.72,  test loss 3.025326, test error 55.65
# Epoch   700, train loss 0.449049, train error 15.47,  test loss 3.353266, test error 56.33
# Epoch   800, train loss 0.411824, train error 13.72,  test loss 3.733319, test error 56.15
# Epoch   900, train loss 0.412183, train error 14.15,  test loss 4.118731, test error 57.10
# Training model with  40 hidden variables
# Epoch     0, train loss 2.095279, train error 77.53,  test loss 2.062138, test error 76.85
# Epoch   100, train loss 0.946484, train error 31.15,  test loss 1.498933, test error 52.92
# Epoch   200, train loss 0.650514, train error 21.30,  test loss 1.950842, test error 54.08
# Epoch   300, train loss 0.508343, train error 17.57,  test loss 2.539947, test error 53.80
# Epoch   400, train loss 0.424531, train error 15.03,  test loss 3.311314, test error 56.42
# Epoch   500, train loss 0.375907, train error 13.35,  test loss 3.927243, test error 55.72
# Epoch   600, train loss 0.328671, train error 12.10,  test loss 4.590832, test error 55.75
# Epoch   700, train loss 0.312230, train error 11.50,  test loss 5.320305, test error 56.17
# Epoch   800, train loss 0.293501, train error 11.15,  test loss 6.038531, test error 56.88
# Epoch   900, train loss 0.287866, train error 10.90,  test loss 6.807514, test error 57.85
# Training model with  45 hidden variables
# Epoch     0, train loss 2.078046, train error 77.22,  test loss 2.050378, test error 76.62
# Epoch   100, train loss 0.814631, train error 26.38,  test loss 1.506134, test error 50.30
# Epoch   200, train loss 0.501139, train error 15.70,  test loss 2.264607, test error 54.50
# Epoch   300, train loss 0.341486, train error 11.25,  test loss 3.295103, test error 55.35
# Epoch   400, train loss 0.235741, train error 7.45,  test loss 4.460312, test error 56.00
# Epoch   500, train loss 0.181370, train error 5.75,  test loss 5.746799, test error 56.88
# Epoch   600, train loss 0.181710, train error 6.60,  test loss 6.977229, test error 57.95
# Epoch   700, train loss 0.020162, train error 0.00,  test loss 8.195009, test error 57.47
# Epoch   800, train loss 0.011430, train error 0.00,  test loss 9.038140, test error 57.83
# Epoch   900, train loss 0.008207, train error 0.00,  test loss 9.669311, test error 57.88
# Training model with  50 hidden variables
# Epoch     0, train loss 2.064642, train error 76.65,  test loss 1.997530, test error 77.03
# Epoch   100, train loss 0.734988, train error 24.05,  test loss 1.613057, test error 51.92
# Epoch   200, train loss 0.352895, train error 11.30,  test loss 2.683932, test error 55.12
# Epoch   300, train loss 0.190995, train error 5.82,  test loss 4.223713, test error 56.28
# Epoch   400, train loss 0.106634, train error 3.10,  test loss 5.749201, test error 56.53
# Epoch   500, train loss 0.013080, train error 0.00,  test loss 6.790043, test error 56.25
# Epoch   600, train loss 0.008099, train error 0.00,  test loss 7.443565, test error 56.30
# Epoch   700, train loss 0.005797, train error 0.00,  test loss 7.913596, test error 56.35
# Epoch   800, train loss 0.004457, train error 0.00,  test loss 8.291331, test error 56.38
# Epoch   900, train loss 0.003600, train error 0.00,  test loss 8.609888, test error 56.55
# Training model with  55 hidden variables
# Epoch     0, train loss 2.088362, train error 77.62,  test loss 2.040383, test error 77.25
# Epoch   100, train loss 0.624686, train error 18.12,  test loss 1.523945, test error 48.55
# Epoch   200, train loss 0.214349, train error 4.97,  test loss 2.774731, test error 52.47
# Epoch   300, train loss 0.042296, train error 0.12,  test loss 4.421931, test error 53.00
# Epoch   400, train loss 0.014923, train error 0.00,  test loss 5.437519, test error 53.72
# Epoch   500, train loss 0.008683, train error 0.00,  test loss 6.028598, test error 54.03
# Epoch   600, train loss 0.005884, train error 0.00,  test loss 6.471855, test error 53.97
# Epoch   700, train loss 0.004402, train error 0.00,  test loss 6.811401, test error 54.08
# Epoch   800, train loss 0.003466, train error 0.00,  test loss 7.081667, test error 54.05
# Epoch   900, train loss 0.002852, train error 0.00,  test loss 7.311555, test error 53.95
# Training model with  60 hidden variables
# Epoch     0, train loss 2.046432, train error 75.80,  test loss 1.976315, test error 75.28
# Epoch   100, train loss 0.501673, train error 14.12,  test loss 1.805078, test error 50.88
# Epoch   200, train loss 0.087689, train error 0.70,  test loss 3.530464, test error 53.90
# Epoch   300, train loss 0.018208, train error 0.00,  test loss 4.795513, test error 54.58
# Epoch   400, train loss 0.008773, train error 0.00,  test loss 5.461568, test error 54.90
# Epoch   500, train loss 0.005571, train error 0.00,  test loss 5.889513, test error 54.80
# Epoch   600, train loss 0.004037, train error 0.00,  test loss 6.213659, test error 54.62
# Epoch   700, train loss 0.003103, train error 0.00,  test loss 6.469648, test error 54.50
# Epoch   800, train loss 0.002513, train error 0.00,  test loss 6.685618, test error 54.62
# Epoch   900, train loss 0.002093, train error 0.00,  test loss 6.865072, test error 54.70
# Training model with  70 hidden variables
# Epoch     0, train loss 2.019723, train error 74.97,  test loss 1.959559, test error 75.20
# Epoch   100, train loss 0.349040, train error 8.75,  test loss 1.939282, test error 51.00
# Epoch   200, train loss 0.034111, train error 0.00,  test loss 3.566933, test error 52.62
# Epoch   300, train loss 0.010987, train error 0.00,  test loss 4.323026, test error 52.75
# Epoch   400, train loss 0.006135, train error 0.00,  test loss 4.766469, test error 53.10
# Epoch   500, train loss 0.004131, train error 0.00,  test loss 5.073238, test error 53.33
# Epoch   600, train loss 0.003060, train error 0.00,  test loss 5.303644, test error 53.30
# Epoch   700, train loss 0.002404, train error 0.00,  test loss 5.490868, test error 53.05
# Epoch   800, train loss 0.001967, train error 0.00,  test loss 5.650740, test error 53.28
# Epoch   900, train loss 0.001654, train error 0.00,  test loss 5.787921, test error 53.15
# Training model with  80 hidden variables
# Epoch     0, train loss 2.020378, train error 74.97,  test loss 1.968186, test error 74.50
# Epoch   100, train loss 0.277581, train error 6.00,  test loss 2.117974, test error 54.03
# Epoch   200, train loss 0.021962, train error 0.00,  test loss 3.573831, test error 53.28
# Epoch   300, train loss 0.008484, train error 0.00,  test loss 4.172878, test error 53.15
# Epoch   400, train loss 0.004975, train error 0.00,  test loss 4.529983, test error 53.22
# Epoch   500, train loss 0.003420, train error 0.00,  test loss 4.783507, test error 53.25
# Epoch   600, train loss 0.002564, train error 0.00,  test loss 4.980598, test error 53.30
# Epoch   700, train loss 0.002028, train error 0.00,  test loss 5.137351, test error 53.22
# Epoch   800, train loss 0.001669, train error 0.00,  test loss 5.269032, test error 53.17
# Epoch   900, train loss 0.001409, train error 0.00,  test loss 5.387129, test error 53.20
# Training model with  90 hidden variables
# Epoch     0, train loss 1.989523, train error 73.93,  test loss 1.912499, test error 74.22
# Epoch   100, train loss 0.121888, train error 0.65,  test loss 2.176159, test error 51.35
# Epoch   200, train loss 0.014190, train error 0.00,  test loss 3.176721, test error 51.70
# Epoch   300, train loss 0.006364, train error 0.00,  test loss 3.583659, test error 51.47
# Epoch   400, train loss 0.003925, train error 0.00,  test loss 3.836924, test error 51.67
# Epoch   500, train loss 0.002763, train error 0.00,  test loss 4.021383, test error 51.78
# Epoch   600, train loss 0.002104, train error 0.00,  test loss 4.162725, test error 51.75
# Epoch   700, train loss 0.001684, train error 0.00,  test loss 4.280661, test error 51.90
# Epoch   800, train loss 0.001395, train error 0.00,  test loss 4.380980, test error 51.92
# Epoch   900, train loss 0.001185, train error 0.00,  test loss 4.467345, test error 51.92
# Training model with 100 hidden variables
# Epoch     0, train loss 2.009390, train error 75.22,  test loss 1.961710, test error 75.50
# Epoch   100, train loss 0.102640, train error 0.28,  test loss 2.127217, test error 50.33
# Epoch   200, train loss 0.012851, train error 0.00,  test loss 3.004750, test error 50.67
# Epoch   300, train loss 0.005884, train error 0.00,  test loss 3.371530, test error 50.90
# Epoch   400, train loss 0.003639, train error 0.00,  test loss 3.595537, test error 51.03
# Epoch   500, train loss 0.002581, train error 0.00,  test loss 3.761771, test error 50.95
# Epoch   600, train loss 0.001971, train error 0.00,  test loss 3.889855, test error 51.03
# Epoch   700, train loss 0.001581, train error 0.00,  test loss 3.995353, test error 50.95
# Epoch   800, train loss 0.001313, train error 0.00,  test loss 4.084124, test error 50.70
# Epoch   900, train loss 0.001117, train error 0.00,  test loss 4.162123, test error 50.70
# Training model with 120 hidden variables
# Epoch     0, train loss 1.980447, train error 73.78,  test loss 1.913189, test error 74.28
# Epoch   100, train loss 0.048661, train error 0.00,  test loss 2.127836, test error 48.90
# Epoch   200, train loss 0.009297, train error 0.00,  test loss 2.701721, test error 48.55
# Epoch   300, train loss 0.004589, train error 0.00,  test loss 2.961348, test error 49.00
# Epoch   400, train loss 0.002944, train error 0.00,  test loss 3.129116, test error 49.03
# Epoch   500, train loss 0.002126, train error 0.00,  test loss 3.254881, test error 49.05
# Epoch   600, train loss 0.001644, train error 0.00,  test loss 3.352954, test error 49.03
# Epoch   700, train loss 0.001329, train error 0.00,  test loss 3.434984, test error 49.05
# Epoch   800, train loss 0.001109, train error 0.00,  test loss 3.505205, test error 49.10
# Epoch   900, train loss 0.000948, train error 0.00,  test loss 3.565445, test error 49.22
# Training model with 140 hidden variables
# Epoch     0, train loss 1.958582, train error 72.65,  test loss 1.885808, test error 73.85
# Epoch   100, train loss 0.039253, train error 0.00,  test loss 2.171420, test error 49.78
# Epoch   200, train loss 0.008229, train error 0.00,  test loss 2.667277, test error 49.83
# Epoch   300, train loss 0.004175, train error 0.00,  test loss 2.899486, test error 49.47
# Epoch   400, train loss 0.002703, train error 0.00,  test loss 3.052926, test error 49.65
# Epoch   500, train loss 0.001962, train error 0.00,  test loss 3.166070, test error 49.72
# Epoch   600, train loss 0.001523, train error 0.00,  test loss 3.255946, test error 49.58
# Epoch   700, train loss 0.001235, train error 0.00,  test loss 3.328566, test error 49.62
# Epoch   800, train loss 0.001033, train error 0.00,  test loss 3.390723, test error 49.58
# Epoch   900, train loss 0.000885, train error 0.00,  test loss 3.445247, test error 49.58
# Training model with 160 hidden variables
# Epoch     0, train loss 1.914643, train error 70.45,  test loss 1.852226, test error 73.03
# Epoch   100, train loss 0.028425, train error 0.00,  test loss 2.114235, test error 48.58
# Epoch   200, train loss 0.007260, train error 0.00,  test loss 2.514283, test error 48.45
# Epoch   300, train loss 0.003800, train error 0.00,  test loss 2.709071, test error 48.62
# Epoch   400, train loss 0.002499, train error 0.00,  test loss 2.840409, test error 48.67
# Epoch   500, train loss 0.001832, train error 0.00,  test loss 2.938768, test error 48.65
# Epoch   600, train loss 0.001430, train error 0.00,  test loss 3.017105, test error 48.88
# Epoch   700, train loss 0.001165, train error 0.00,  test loss 3.081948, test error 48.83
# Epoch   800, train loss 0.000978, train error 0.00,  test loss 3.138034, test error 48.80
# Epoch   900, train loss 0.000839, train error 0.00,  test loss 3.187431, test error 48.70
# Training model with 180 hidden variables
# Epoch     0, train loss 1.917179, train error 69.80,  test loss 1.837650, test error 70.78
# Epoch   100, train loss 0.023865, train error 0.00,  test loss 2.014008, test error 47.78
# Epoch   200, train loss 0.006508, train error 0.00,  test loss 2.360605, test error 47.60
# Epoch   300, train loss 0.003488, train error 0.00,  test loss 2.535045, test error 47.78
# Epoch   400, train loss 0.002314, train error 0.00,  test loss 2.652839, test error 47.80
# Epoch   500, train loss 0.001704, train error 0.00,  test loss 2.740473, test error 47.72
# Epoch   600, train loss 0.001336, train error 0.00,  test loss 2.810027, test error 47.65
# Epoch   700, train loss 0.001091, train error 0.00,  test loss 2.868975, test error 47.78
# Epoch   800, train loss 0.000918, train error 0.00,  test loss 2.919670, test error 47.78
# Epoch   900, train loss 0.000789, train error 0.00,  test loss 2.963223, test error 47.85
# Training model with 200 hidden variables
# Epoch     0, train loss 1.943379, train error 70.93,  test loss 1.856261, test error 70.88
# Epoch   100, train loss 0.021208, train error 0.00,  test loss 2.019914, test error 47.58
# Epoch   200, train loss 0.006071, train error 0.00,  test loss 2.331998, test error 47.53
# Epoch   300, train loss 0.003288, train error 0.00,  test loss 2.493090, test error 47.62
# Epoch   400, train loss 0.002194, train error 0.00,  test loss 2.600878, test error 47.50
# Epoch   500, train loss 0.001622, train error 0.00,  test loss 2.683518, test error 47.42
# Epoch   600, train loss 0.001274, train error 0.00,  test loss 2.749047, test error 47.35
# Epoch   700, train loss 0.001042, train error 0.00,  test loss 2.804136, test error 47.33
# Epoch   800, train loss 0.000878, train error 0.00,  test loss 2.851251, test error 47.20
# Epoch   900, train loss 0.000756, train error 0.00,  test loss 2.892669, test error 47.25
# Training model with 250 hidden variables
# Epoch     0, train loss 1.885508, train error 68.03,  test loss 1.815225, test error 71.03
# Epoch   100, train loss 0.016870, train error 0.00,  test loss 1.892419, test error 47.38
# Epoch   200, train loss 0.005306, train error 0.00,  test loss 2.137542, test error 47.30
# Epoch   300, train loss 0.002948, train error 0.00,  test loss 2.267792, test error 47.00
# Epoch   400, train loss 0.001991, train error 0.00,  test loss 2.357549, test error 47.17
# Epoch   500, train loss 0.001483, train error 0.00,  test loss 2.425283, test error 47.15
# Epoch   600, train loss 0.001170, train error 0.00,  test loss 2.480599, test error 47.05
# Epoch   700, train loss 0.000961, train error 0.00,  test loss 2.527107, test error 47.00
# Epoch   800, train loss 0.000812, train error 0.00,  test loss 2.567069, test error 47.00
# Epoch   900, train loss 0.000700, train error 0.00,  test loss 2.601777, test error 47.00
# Training model with 300 hidden variables
# Epoch     0, train loss 1.899894, train error 69.70,  test loss 1.836342, test error 71.47
# Epoch   100, train loss 0.014406, train error 0.00,  test loss 1.899409, test error 47.03
# Epoch   200, train loss 0.004792, train error 0.00,  test loss 2.122522, test error 46.78
# Epoch   300, train loss 0.002712, train error 0.00,  test loss 2.241320, test error 46.88
# Epoch   400, train loss 0.001848, train error 0.00,  test loss 2.325455, test error 46.85
# Epoch   500, train loss 0.001382, train error 0.00,  test loss 2.388827, test error 46.95
# Epoch   600, train loss 0.001095, train error 0.00,  test loss 2.440107, test error 46.83
# Epoch   700, train loss 0.000901, train error 0.00,  test loss 2.483943, test error 46.88
# Epoch   800, train loss 0.000763, train error 0.00,  test loss 2.521167, test error 46.92
# Epoch   900, train loss 0.000659, train error 0.00,  test loss 2.554172, test error 46.92
# Training model with 400 hidden variables
# Epoch     0, train loss 1.863108, train error 63.72,  test loss 1.790576, test error 68.10
# Epoch   100, train loss 0.011880, train error 0.00,  test loss 1.754917, test error 45.38
# Epoch   200, train loss 0.004222, train error 0.00,  test loss 1.934186, test error 45.60
# Epoch   300, train loss 0.002446, train error 0.00,  test loss 2.033465, test error 45.33
# Epoch   400, train loss 0.001683, train error 0.00,  test loss 2.103058, test error 45.40
# Epoch   500, train loss 0.001269, train error 0.00,  test loss 2.155647, test error 45.20
# Epoch   600, train loss 0.001009, train error 0.00,  test loss 2.199466, test error 45.20
# Epoch   700, train loss 0.000834, train error 0.00,  test loss 2.236366, test error 45.12
# Epoch   800, train loss 0.000708, train error 0.00,  test loss 2.267677, test error 45.25
# Epoch   900, train loss 0.000613, train error 0.00,  test loss 2.295210, test error 45.17

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
